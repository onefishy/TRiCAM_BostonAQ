# %%
import numpy as np
import scipy as sp
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
# %matplotlib inline

# %%
# API KEY = f71059696f42912d
# http://api.wunderground.com/api/f71059696f42912d/forecast/geolookup/conditions/q/MA/Boston.json

# %%
grid = pd.read_csv('/Users/Annamira/Documents/GitHub/grid_points.csv', index_col=0)
grid
# Out:
#                                0                            1  \
# 0        [-71.20197   42.291441]  [-71.20195608  42.291441  ]
# 1    [-71.20197     42.29144864]  [-71.20195608  42.29144864]
# 2    [-71.20197     42.29145628]  [-71.20195608  42.29145628]
# 3    [-71.20197     42.29146392]  [-71.20195608  42.29146392]
# 4    [-71.20197     42.29147156]  [-71.20195608  42.29147156]
# 5    [-71.20197     42.29147921]  [-71.20195608  42.29147921]
# 6    [-71.20197     42.29148685]  [-71.20195608  42.29148685]
# 7    [-71.20197     42.29149449]  [-71.20195608  42.29149449]
# 8    [-71.20197     42.29150213]  [-71.20195608  42.29150213]
# 9    [-71.20197     42.29150977]  [-71.20195608  42.29150977]
# 10   [-71.20197     42.29151741]  [-71.20195608  42.29151741]
# 11   [-71.20197     42.29152505]  [-71.20195608  42.29152505]
# 12   [-71.20197     42.29153269]  [-71.20195608  42.29153269]
# 13   [-71.20197     42.29154034]  [-71.20195608  42.29154034]
# ...

# %%
str1 = '[-71.20174734  42.29144864]'
str2 = '[-71.20173343  42.29144864]'
print(str1.split(' '))
# Out:
# ['[-71.20174734', '', '42.29144864]']

# %%
# write new grid of center of cells

y = np.empty([131], dtype=object)
x = np.empty([131], dtype=object)

for col in range(0, 130):
    hold = grid[str(col)][1]
    hold2 = hold.split(' ')
    hold3 = hold2[0]
    #if len(hold2) > 2:
        #hold3 = hold2[2]
    #else:
        #hold3 = hold2[1]
    val = hold3[1:]
    x[int(col)] = val
    
for row in range(0, 130):
    hold = grid['0'][row]
    hold2 = hold.split(' ')
    hold3 = ''
    hold3 = hold2[len(hold2) - 1]
    val = hold3[:-1]
    y[int(row)] = val

    
print(y)
        

'''
import the grid
write new grid of center of cells

for each cell in grid
    check (based on center of each cell) which station is closest
    assign value of station to cell

'''
# Out:
# ['42.291441' '42.29144864' '42.29145628' '42.29146392' '42.29147156'
#  '42.29147921' '42.29148685' '42.29149449' '42.29150213' '42.29150977'
#  '42.29151741' '42.29152505' '42.29153269' '42.29154034' '42.29154798'
#  '42.29155562' '42.29156326' '42.2915709' '42.29157854' '42.29158618'
#  '42.29159382' '42.29160147' '42.29160911' '42.29161675' '42.29162439'
#  '42.29163203' '42.29163967' '42.29164731' '42.29165495' '42.2916626'
#  '42.29167024' '42.29167788' '42.29168552' '42.29169316' '42.2917008'
#  '42.29170844' '42.29171608' '42.29172373' '42.29173137' '42.29173901'
#  '42.29174665' '42.29175429' '42.29176193' '42.29176957' '42.29177721'
#  '42.29178486' '42.2917925' '42.29180014' '42.29180778' '42.29181542'
#  '42.29182306' '42.2918307' '42.29183834' '42.29184599' '42.29185363'
#  '42.29186127' '42.29186891' '42.29187655' '42.29188419' '42.29189183'
#  '42.29189947' '42.29190712' '42.29191476' '42.2919224' '42.29193004'
# ...
